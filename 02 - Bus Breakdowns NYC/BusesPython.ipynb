# %% [markdown]
# # Breakdowns of School Buses in NYC 🚌💥

# %% [markdown]
# ## Initial Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import re

# %%
df = pd.read_csv("C:/Users/mathi/OneDrive/Python/Data too Large to Push/bus-breakdowns-delays.csv")
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_3256\2084199699.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545691 entries, 0 to 545690
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   School_Year                      545691 non-null  object
#  1   Busbreakdown_ID                  545691 non-null  int64
#  2   Run_Type                         545685 non-null  object
#  3   Bus_No                           545678 non-null  object
#  4   Route_Number                     545684 non-null  object
#  5   Reason                           545689 non-null  object
#  6   Schools_Serviced                 545684 non-null  object
#  7   Occurred_On                      545691 non-null  object
#  8   Created_On                       545691 non-null  object
#  9   Boro                             534474 non-null  object
#  10  Bus_Company_Name                 545691 non-null  object
#  11  How_Long_Delayed                 491627 non-null  object
#  12  Number_Of_Students_On_The_Bus    545691 non-null  int64
#  13  Has_Contractor_Notified_Schools  545691 non-null  object
#  14  Has_Contractor_Notified_Parents  545691 non-null  object
#  15  Have_You_Alerted_OPT             545691 non-null  object
#  16  Informed_On                      545691 non-null  object
#  17  Incident_Number                  10890 non-null   object
#  18  Last_Updated_On                  545691 non-null  object
#  19  Breakdown_or_Running_Late        545691 non-null  object
#  20  School_Age_or_PreK               545691 non-null  object
# dtypes: int64(2), object(19)
# memory usage: 87.4+ MB

# %%
df.head()
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
# 2   2015-2016          1227540           Pre-K/EI    418            3
# 3   2015-2016          1227541  Special Ed AM Run   4522         M271
# 4   2015-2016          1227542  Special Ed AM Run   3124         M373
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
# 2  Heavy Traffic             C445  11/05/2015 08:09:00 AM
# 3  Heavy Traffic            02699  11/05/2015 08:12:00 AM
# 4  Heavy Traffic            02116  11/05/2015 08:13:00 AM
#
#                Created_On        Boro  ... How_Long_Delayed  \
# 0  11/05/2015 08:12:00 AM  New Jersey  ...              NaN
# 1  11/05/2015 08:12:00 AM   Manhattan  ...            20MNS
# 2  11/05/2015 08:13:00 AM       Bronx  ...            15MIN
# 3  11/05/2015 08:14:00 AM   Manhattan  ...           15 MIN
# 4  11/05/2015 08:14:00 AM   Manhattan  ...              NaN
#
#   Number_Of_Students_On_The_Bus  Has_Contractor_Notified_Schools  \
# 0                            11                              Yes
# 1                             2                              Yes
# 2                             8                              Yes
# 3                             6                               No
# 4                             6                               No
#
#   Has_Contractor_Notified_Parents Have_You_Alerted_OPT  \
# 0                              No                  Yes
# 1                             Yes                   No
# 2                             Yes                  Yes
# 3                              No                   No
# 4                              No                   No
#
#               Informed_On Incident_Number         Last_Updated_On  \
# 0  11/05/2015 08:12:00 AM             NaN  11/05/2015 08:12:14 AM
# 1  11/05/2015 08:12:00 AM             NaN  11/05/2015 08:13:34 AM
# 2  11/05/2015 08:13:00 AM             NaN  11/05/2015 08:13:22 AM
# 3  11/05/2015 08:14:00 AM             NaN  11/05/2015 08:14:04 AM
# 4  11/05/2015 08:14:00 AM             NaN  11/05/2015 08:14:08 AM
#
#   Breakdown_or_Running_Late School_Age_or_PreK
# 0              Running Late         School-Age
# 1              Running Late         School-Age
# 2              Running Late              Pre-K
# 3              Running Late         School-Age
# 4              Running Late         School-Age
#
# [5 rows x 21 columns]

# %% [markdown]
# Initial preprocessing:
# - add helper column for whether delay time contains "min"
# - parse `school_year`
# - parse `how_long_delayed`
# - parse date columns

# %%
# Parse school year column
df["School_Year"] = df["School_Year"].apply(lambda x: re.search('\d+', x).group()).astype(int)

# %%
# Parse data columns
df["Occurred_On"] = pd.to_datetime(df["Occurred_On"], format="%m/%d/%Y %I:%M:%S %p")
df["Created_On"] = pd.to_datetime(df["Created_On"], format="%m/%d/%Y %I:%M:%S %p")
df["Informed_On"] = pd.to_datetime(df["Informed_On"], format="%m/%d/%Y %I:%M:%S %p")
df["Last_Updated_On"] = pd.to_datetime(df["Last_Updated_On"], format="%m/%d/%Y %I:%M:%S %p")

# %%
# Filter down to the ones that have minutes in delay column
df = df.loc[df["How_Long_Delayed"].str.lower().str.contains("min").fillna(False)]

# %%
# Parse delay to number
df["How_Long_Delayed"] = df["How_Long_Delayed"].str.extract('(\d+)').fillna(0).astype(int)

# %%
data = df.reset_index()

# %%
data.head()
# Out:
#    index  School_Year  Busbreakdown_ID           Run_Type  Bus_No  \
# 0      2         2015          1227540           Pre-K/EI     418
# 1      3         2015          1227541  Special Ed AM Run    4522
# 2      5         2015          1227543  Special Ed AM Run  HT1502
# 3      6         2015          1227544  Special Ed AM Run     142
# 4      8         2015          1227546  Special Ed AM Run   56102
#
#   Route_Number         Reason Schools_Serviced         Occurred_On  \
# 0            3  Heavy Traffic             C445 2015-11-05 08:09:00
# 1         M271  Heavy Traffic            02699 2015-11-05 08:12:00
# 2         W796  Heavy Traffic            75407 2015-11-05 07:58:00
# 3         W633  Heavy Traffic            75670 2015-11-05 08:24:00
# 4         M126  Heavy Traffic            01450 2015-11-05 07:55:00
#
#            Created_On  ... How_Long_Delayed Number_Of_Students_On_The_Bus  \
# 0 2015-11-05 08:13:00  ...               15                             8
# 1 2015-11-05 08:14:00  ...               15                             6
# 2 2015-11-05 08:14:00  ...               30                             1
# 3 2015-11-05 08:15:00  ...               20                             3
# 4 2015-11-05 08:17:00  ...               30                             5
#
#    Has_Contractor_Notified_Schools  Has_Contractor_Notified_Parents  \
# 0                              Yes                              Yes
# 1                               No                               No
# 2                              Yes                              Yes
# 3                              Yes                               No
# 4                              Yes                              Yes
#
#   Have_You_Alerted_OPT         Informed_On Incident_Number  \
# 0                  Yes 2015-11-05 08:13:00             NaN
# 1                   No 2015-11-05 08:14:00             NaN
# 2                  Yes 2015-11-05 08:14:00             NaN
# 3                   No 2015-11-05 08:15:00             NaN
# 4                  Yes 2015-11-05 08:17:00             NaN
#
#       Last_Updated_On Breakdown_or_Running_Late School_Age_or_PreK
# 0 2015-11-05 08:13:22              Running Late              Pre-K
# 1 2015-11-05 08:14:04              Running Late         School-Age
# 2 2015-11-05 08:14:15              Running Late         School-Age
# 3 2015-11-05 08:16:53              Running Late         School-Age
# 4 2015-11-05 08:17:07              Running Late         School-Age
#
# [5 rows x 22 columns]

# %% [markdown]
# And we are good to good!

# %% [markdown]
# ## Data Wrangling / Visualisation Section
#
# Questions I want to explore visually:
# 1. Breakdowns by year broken down by borough:
#     - 2020 was a good year for breakdowns, though that is not due to the drivers or companies (the mean C word)

# %%
chart1_data = (data
    .value_counts(["Boro", "School_Year"])
    .reset_index(name="count")
    # Assign new column that divides count by the sum for each group
    # The trick here is that "transform" gives back a series of 
    # the same length as the count column!
    .assign(count = lambda x: x["count"] / x.groupby("Boro")["count"].transform("sum"))    
)

# %%
sns.set(rc={'figure.figsize': (8, 3)})

ax = sns.lineplot(data=chart1_data, x="School_Year", y="count", hue="Boro")
ax.set(title="Breakdowns (normalised) for each borough by year", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# At this point, realising how cumbersome data visualisation outside of ggplot2 is... Might just focus on the data wrangling in pandas for the next ones:

# %% [markdown]
# 2. Breakdowns by year broken down by company:
#     - Here, need to filter down the number of companies, let's pick top 10 most frequent ones.
#     - Impact of Covid shows the same pattern, otherwise no discernible trend over time

# %%
biggest_companies = (data
    .value_counts(["Bus_Company_Name"])
    .reset_index(name="count")
    .nlargest(columns="count", n=10)["Bus_Company_Name"]
    .tolist()
)

biggest_companies
# Out:
# ['LEESEL TRANSPORTATION CORP (B2192)',
#  'PIONEER TRANSPORTATION CORP',
#  'G.V.C., LTD.',
#  'BORO TRANSIT, INC.',
#  'RELIANT TRANSPORTATION, INC (B2321)',
#  'VAN TRANS LLC (B2192)',
#  'HOYT TRANSPORTATION CORP.',
#  'ALLIED TRANSIT CORP.',
#  'PRIDE TRANSPORTATION (SCH AGE)',
#  'L & M BUS CORP.']

# %%
chart2_data = (data
    .query("Bus_Company_Name in @biggest_companies")
    .value_counts(["School_Year", "Bus_Company_Name"])
    .reset_index(name="count")
    .assign(count = lambda x: x["count"] / x.groupby("Bus_Company_Name")["count"].transform("sum"))
)

chart2_data
# Out:
#     School_Year                     Bus_Company_Name     count
# 0          2018   LEESEL TRANSPORTATION CORP (B2192)  0.417254
# 1          2019   LEESEL TRANSPORTATION CORP (B2192)  0.201864
# 2          2021   LEESEL TRANSPORTATION CORP (B2192)  0.162252
# 3          2017          PIONEER TRANSPORTATION CORP  0.281732
# 4          2018  RELIANT TRANSPORTATION, INC (B2321)  0.388222
# ..          ...                                  ...       ...
# 69         2020                         G.V.C., LTD.  0.019157
# 70         2020                 ALLIED TRANSIT CORP.  0.007506
# 71         2016          PIONEER TRANSPORTATION CORP  0.001205
# 72         2015          PIONEER TRANSPORTATION CORP  0.000723
# 73         2016       PRIDE TRANSPORTATION (SCH AGE)  0.000303
#
# [74 rows x 3 columns]

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.lineplot(data=chart2_data, x="School_Year", y="count", hue="Bus_Company_Name")
ax.set(title="Breakdowns (normalised) for each bus company (biggest 10) by year", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# 3. How long the buses are delayed
#     - over time
#     - by company/borough

# %%
# Mean delay by year
(data
    .groupby("School_Year")
    .agg(mean_delay = ("How_Long_Delayed", np.mean))
    .reset_index()
)
# Out:
#    School_Year  mean_delay
# 0         2015   24.476783
# 1         2016   25.539981
# 2         2017   24.357645
# 3         2018   29.636872
# 4         2019   26.666013
# 5         2020   27.904188
# 6         2021   27.412048
# 7         2022   33.243346

# %% [markdown]
# Looks like average delays have not changed in recent years. Let's see the development by borough:

# %%
chart3_data = (data
    .dropna(subset="Boro")
    .groupby(["School_Year", "Boro"], as_index=False)
    .agg(mean_delay = ("How_Long_Delayed", np.mean))
)

chart3_data
# Out:
#     School_Year             Boro  mean_delay
# 0          2015     All Boroughs   30.762195
# 1          2015            Bronx   19.760874
# 2          2015         Brooklyn   30.293434
# 3          2015      Connecticut   24.375000
# 4          2015        Manhattan   25.192444
# ..          ...              ...         ...
# 83         2022       New Jersey   28.963964
# 84         2022           Queens   36.842200
# 85         2022  Rockland County   32.356322
# 86         2022    Staten Island   38.223675
# 87         2022      Westchester   30.719960
#
# [88 rows x 3 columns]

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.lineplot(data=chart3_data, x="School_Year", y="mean_delay", hue="Boro")
ax.set(title="Average Delay Time by Borough", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.lineplot(data=chart3_data.query("Boro == 'Manhattan'"),
                  x="School_Year", y="mean_delay", hue="Boro")
ax.set(title="Looks like Manhattan is having a crisis", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# 3. How long the buses are delayed
#     - over time
#     - by company/borough

# %% [markdown]
# ## Big learning: Can just use "count" **inside** `agg`, instead of adding count and then aggregating to unique

# %%
chart4_data = (data
    .groupby(["School_Year", "Boro"], as_index=False)
    .agg(students_affected = ("Number_Of_Students_On_The_Bus", np.sum),
         buses = ("Boro", "count"))
    .assign(per_boro = lambda x: x["students_affected"] / x["buses"])
)

chart4_data
# Out:
#     School_Year             Boro  students_affected  buses  per_boro
# 0          2015     All Boroughs                426    164  2.597561
# 1          2015            Bronx              58694  13679  4.290811
# 2          2015         Brooklyn              47225  10752  4.392206
# 3          2015      Connecticut                 37     24  1.541667
# 4          2015        Manhattan              23004   7358  3.126393
# ..          ...              ...                ...    ...       ...
# 83         2022       New Jersey                240    111  2.162162
# 84         2022           Queens              14039   7237  1.939892
# 85         2022  Rockland County                224     87  2.574713
# 86         2022    Staten Island               5120   7037  0.727583
# 87         2022      Westchester               2482   1007  2.464747
#
# [88 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.lineplot(data=chart4_data,
                  x="School_Year", y="per_boro", hue="Boro")
ax.set(title="Well, that's uninformative", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
chart4_data = (data
    .groupby(["Boro"], as_index=False)
    .agg(students_affected = ("Number_Of_Students_On_The_Bus", np.sum),
         buses = ("Boro", "count"))
    .assign(per_boro = lambda x: x["students_affected"] / x["buses"])
    .sort_values("per_boro", ascending=False)
    .reset_index(drop=True)
    .style.bar(subset="per_boro", color="firebrick")
)

chart4_data
# Out:
# <style type="text/css">
# #T_9057b_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 100.0%, transparent 100.0%);
# }
# #T_9057b_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 90.2%, transparent 90.2%);
# }
# #T_9057b_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 80.2%, transparent 80.2%);
# }
# #T_9057b_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 65.6%, transparent 65.6%);
# }
# #T_9057b_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 59.7%, transparent 59.7%);
# }
# #T_9057b_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 56.4%, transparent 56.4%);
# }
# #T_9057b_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 43.3%, transparent 43.3%);
# }
# #T_9057b_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 30.7%, transparent 30.7%);
# }
# #T_9057b_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 25.5%, transparent 25.5%);
# }
# #T_9057b_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 19.0%, transparent 19.0%);
# }
# #T_9057b_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 15.0%, transparent 15.0%);
# }
# </style>
# <table id="T_9057b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9057b_level0_col0" class="col_heading level0 col0" >Boro</th>
#       <th id="T_9057b_level0_col1" class="col_heading level0 col1" >students_affected</th>
#       <th id="T_9057b_level0_col2" class="col_heading level0 col2" >buses</th>
#       <th id="T_9057b_level0_col3" class="col_heading level0 col3" >per_boro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9057b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9057b_row0_col0" class="data row0 col0" >New Jersey</td>
#       <td id="T_9057b_row0_col1" class="data row0 col1" >13932</td>
#       <td id="T_9057b_row0_col2" class="data row0 col2" >2336</td>
#       <td id="T_9057b_row0_col3" class="data row0 col3" >5.964041</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9057b_row1_col0" class="data row1 col0" >Rockland County</td>
#       <td id="T_9057b_row1_col1" class="data row1 col1" >5758</td>
#       <td id="T_9057b_row1_col2" class="data row1 col2" >1070</td>
#       <td id="T_9057b_row1_col3" class="data row1 col3" >5.381308</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9057b_row2_col0" class="data row2 col0" >Bronx</td>
#       <td id="T_9057b_row2_col1" class="data row2 col1" >548587</td>
#       <td id="T_9057b_row2_col2" class="data row2 col2" >114655</td>
#       <td id="T_9057b_row2_col3" class="data row2 col3" >4.784676</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9057b_row3_col0" class="data row3 col0" >Queens</td>
#       <td id="T_9057b_row3_col1" class="data row3 col1" >246492</td>
#       <td id="T_9057b_row3_col2" class="data row3 col2" >63019</td>
#       <td id="T_9057b_row3_col3" class="data row3 col3" >3.911392</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9057b_row4_col0" class="data row4 col0" >Brooklyn</td>
#       <td id="T_9057b_row4_col1" class="data row4 col1" >384048</td>
#       <td id="T_9057b_row4_col2" class="data row4 col2" >107790</td>
#       <td id="T_9057b_row4_col3" class="data row4 col3" >3.562928</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9057b_row5_col0" class="data row5 col0" >Nassau County</td>
#       <td id="T_9057b_row5_col1" class="data row5 col1" >47152</td>
#       <td id="T_9057b_row5_col2" class="data row5 col2" >14023</td>
#       <td id="T_9057b_row5_col3" class="data row5 col3" >3.362476</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9057b_row6_col0" class="data row6 col0" >Westchester</td>
#       <td id="T_9057b_row6_col1" class="data row6 col1" >26353</td>
#       <td id="T_9057b_row6_col2" class="data row6 col2" >10206</td>
#       <td id="T_9057b_row6_col3" class="data row6 col3" >2.582109</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9057b_row7_col0" class="data row7 col0" >All Boroughs</td>
#       <td id="T_9057b_row7_col1" class="data row7 col1" >2321</td>
#       <td id="T_9057b_row7_col2" class="data row7 col2" >1269</td>
#       <td id="T_9057b_row7_col3" class="data row7 col3" >1.828999</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9057b_row8_col0" class="data row8 col0" >Manhattan</td>
#       <td id="T_9057b_row8_col1" class="data row8 col1" >188578</td>
#       <td id="T_9057b_row8_col2" class="data row8 col2" >123860</td>
#       <td id="T_9057b_row8_col3" class="data row8 col3" >1.522509</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9057b_row9_col0" class="data row9 col0" >Staten Island</td>
#       <td id="T_9057b_row9_col1" class="data row9 col1" >28237</td>
#       <td id="T_9057b_row9_col2" class="data row9 col2" >24976</td>
#       <td id="T_9057b_row9_col3" class="data row9 col3" >1.130565</td>
#     </tr>
#     <tr>
#       <th id="T_9057b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9057b_row10_col0" class="data row10 col0" >Connecticut</td>
#       <td id="T_9057b_row10_col1" class="data row10 col1" >330</td>
#       <td id="T_9057b_row10_col2" class="data row10 col2" >370</td>
#       <td id="T_9057b_row10_col3" class="data row10 col3" >0.891892</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looks like New Jersey has the most crowded buses. Still very low number of people on a bus on average, it seems like...

# %% [markdown]
# 5. Which reasons occur most frequently at which times in
#     - the week
#     - a day

# %%
data["hour"] = data["Occurred_On"].dt.hour
data["month"] = data["Occurred_On"].dt.month
data["day"] = data["Occurred_On"].dt.day_of_year

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.lineplot(data=chart4_data,
                  x="School_Year", y="per_boro", hue="Boro")
ax.set(title="Well, that's uninformative", xlabel=None,
       ylabel=None)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.histplot(data=data["hour"], binwidth=1)
ax.set(title="Most breakdowns and delays occur in the morning")
plt.show()

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.histplot(data[["day"]], binwidth=1)
ax.set(title="In Summer, few buses are running")
plt.show()

# %%
chart5_data = (data
    .value_counts(["Reason", "hour"])
    .reset_index(name="count")
)

chart5_data
# Out:
#                  Reason  hour   count
# 0         Heavy Traffic     7  129289
# 1         Heavy Traffic     6   91223
# 2         Heavy Traffic     8   35204
# 3                 Other     7   26164
# 4         Heavy Traffic    14   25083
# ..                  ...   ...     ...
# 205  Mechanical Problem    22       1
# 206           Flat Tire    20       1
# 207  Weather Conditions    20       1
# 208           Flat Tire    19       1
# 209  Mechanical Problem    23       1
#
# [210 rows x 3 columns]

# %%
ax = sns.catplot(chart5_data, x="hour", y="count", row="Reason", color="midnightblue",
            kind="bar", sharex=False, sharey=False, height=2, aspect=3)
ax.fig.subplots_adjust(top=0.95)
ax.fig.suptitle("Breakdown reason frequency by hour in the day")
plt.show()

# %%
data["week"] = data["Occurred_On"].dt.week

chart6_data = (data
    .value_counts(["week", "Reason"])
    .reset_index(name="count")
)

chart6_data
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_3256\107869240.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#      week                       Reason  count
# 0      43                Heavy Traffic  12475
# 1      44                Heavy Traffic  11694
# 2      42                Heavy Traffic  11488
# 3      39                Heavy Traffic  11387
# 4      40                Heavy Traffic  11043
# ..    ...                          ...    ...
# 504    52                  Problem Run      1
# 505    31           Weather Conditions      1
# 506    33                  Problem Run      1
# 507    34                        Other      1
# 508    35  Late return from Field Trip      1
#
# [509 rows x 3 columns]

# %%
ax = sns.catplot(chart6_data, x="week", y="count", row="Reason", color="midnightblue",
            kind="bar", sharex=False, sharey=False, height=2, aspect=4)
ax.fig.subplots_adjust(top=0.95)
ax.fig.suptitle("Breakdown reason frequency by week in the year")
plt.show()

# %% [markdown]
# 6. Average delay by reason of delay

# %%
chart7_data = (data
    .groupby("Reason")
    .agg(mean_delay = ("How_Long_Delayed", np.mean))
    .reset_index()
    .sort_values("mean_delay", ascending=False)
)

chart7_data.reset_index(drop=True).style.bar("mean_delay", color="firebrick")
# Out:
# <style type="text/css">
# #T_48571_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 100.0%, transparent 100.0%);
# }
# #T_48571_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 94.7%, transparent 94.7%);
# }
# #T_48571_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 84.4%, transparent 84.4%);
# }
# #T_48571_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 84.1%, transparent 84.1%);
# }
# #T_48571_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 81.7%, transparent 81.7%);
# }
# #T_48571_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 77.0%, transparent 77.0%);
# }
# #T_48571_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 70.3%, transparent 70.3%);
# }
# #T_48571_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 69.1%, transparent 69.1%);
# }
# #T_48571_row8_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 68.4%, transparent 68.4%);
# }
# #T_48571_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, firebrick 51.3%, transparent 51.3%);
# }
# </style>
# <table id="T_48571">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48571_level0_col0" class="col_heading level0 col0" >Reason</th>
#       <th id="T_48571_level0_col1" class="col_heading level0 col1" >mean_delay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48571_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48571_row0_col0" class="data row0 col0" >Accident</td>
#       <td id="T_48571_row0_col1" class="data row0 col1" >38.013761</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48571_row1_col0" class="data row1 col0" >Problem Run</td>
#       <td id="T_48571_row1_col1" class="data row1 col1" >36.001287</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48571_row2_col0" class="data row2 col0" >Flat Tire</td>
#       <td id="T_48571_row2_col1" class="data row2 col1" >32.093414</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48571_row3_col0" class="data row3 col0" >Mechanical Problem</td>
#       <td id="T_48571_row3_col1" class="data row3 col1" >31.980808</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48571_row4_col0" class="data row4 col0" >Won`t Start</td>
#       <td id="T_48571_row4_col1" class="data row4 col1" >31.068774</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48571_row5_col0" class="data row5 col0" >Other</td>
#       <td id="T_48571_row5_col1" class="data row5 col1" >29.264450</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48571_row6_col0" class="data row6 col0" >Weather Conditions</td>
#       <td id="T_48571_row6_col1" class="data row6 col1" >26.710125</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_48571_row7_col0" class="data row7 col0" >Late return from Field Trip</td>
#       <td id="T_48571_row7_col1" class="data row7 col1" >26.284700</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_48571_row8_col0" class="data row8 col0" >Heavy Traffic</td>
#       <td id="T_48571_row8_col1" class="data row8 col1" >26.007269</td>
#     </tr>
#     <tr>
#       <th id="T_48571_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_48571_row9_col0" class="data row9 col0" >Delayed by School</td>
#       <td id="T_48571_row9_col1" class="data row9 col1" >19.500821</td>
#     </tr>
#   </tbody>
# </table>

# %%
list(sns.color_palette()[9])
# Out:
# [0.39215686274509803, 0.7098039215686275, 0.803921568627451]

# %%
sns.set(rc={'figure.figsize': (6, 3)})

ax = sns.barplot(chart7_data, x="mean_delay", y="Reason", color="midnightblue")
ax.set(title="Average Delay by Reason of Delay", xlabel="Minutes",
       ylabel=None)

plt.show()

# %% [markdown]
# # That's it!
