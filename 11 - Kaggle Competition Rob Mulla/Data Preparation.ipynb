# %% [markdown]
# ### Predicting sleep pattern

# %%
import pandas as pd
import numpy as np
from plotnine import *

pd.set_option('display.max.columns', 500)
pd.set_option('display.max.rows', 100)

# %% [markdown]
# ### Reading in and cleaning the data

# %% [markdown]
# #### Parsing the XML data to csv

# %%
# -*- coding: utf-8 -*-
"""
applehealthdata.py: Extract data from Apple Health App's export.xml.
Copyright (c) 2016 Nicholas J. Radcliffe
Licence: MIT
"""
import os
import re
import sys

from xml.etree import ElementTree
from collections import Counter, OrderedDict

__version__ = '1.3'

RECORD_FIELDS = OrderedDict((
    ('sourceName', 's'),
    ('sourceVersion', 's'),
    ('device', 's'),
    ('type', 's'),
    ('unit', 's'),
    ('creationDate', 'd'),
    ('startDate', 'd'),
    ('endDate', 'd'),
    ('value', 'n'),
))

ACTIVITY_SUMMARY_FIELDS = OrderedDict((
    ('dateComponents', 'd'),
    ('activeEnergyBurned', 'n'),
    ('activeEnergyBurnedGoal', 'n'),
    ('activeEnergyBurnedUnit', 's'),
    ('appleExerciseTime', 's'),
    ('appleExerciseTimeGoal', 's'),
    ('appleStandHours', 'n'),
    ('appleStandHoursGoal', 'n'),
))

WORKOUT_FIELDS = OrderedDict((
    ('sourceName', 's'),
    ('sourceVersion', 's'),
    ('device', 's'),
    ('creationDate', 'd'),
    ('startDate', 'd'),
    ('endDate', 'd'),
    ('workoutActivityType', 's'),
    ('duration', 'n'),
    ('durationUnit', 's'),
    ('totalDistance', 'n'),
    ('totalDistanceUnit', 's'),
    ('totalEnergyBurned', 'n'),
    ('totalEnergyBurnedUnit', 's'),
))

FIELDS = {
    'Record': RECORD_FIELDS,
    'ActivitySummary': ACTIVITY_SUMMARY_FIELDS,
    'Workout': WORKOUT_FIELDS,
}


PREFIX_RE = re.compile('^HK.*TypeIdentifier(.+)$')
ABBREVIATE = True
VERBOSE = True

def format_freqs(counter):
    """
    Format a counter object for display.
    """
    return '\n'.join('%s: %d' % (tag, counter[tag])
                     for tag in sorted(counter.keys()))


def format_value(value, datatype):
    """
    Format a value for a CSV file, escaping double quotes and backslashes.
    None maps to empty.
    datatype should be
        's' for string (escaped)
        'n' for number
        'd' for datetime
    """
    if value is None:
        return ''
    elif datatype == 's':  # string
        return '"%s"' % value.replace('\\', '\\\\').replace('"', '\\"')
    elif datatype in ('n', 'd'):  # number or date
        return value
    else:
        raise KeyError('Unexpected format value: %s' % datatype)


def abbreviate(s, enabled=ABBREVIATE):
    """
    Abbreviate particularly verbose strings based on a regular expression
    """
    m = re.match(PREFIX_RE, s)
    return m.group(1) if enabled and m else s


class HealthDataExtractor(object):
    """
    Extract health data from Apple Health App's XML export, export.xml.
    Inputs:
        path:      Relative or absolute path to export.xml
        verbose:   Set to False for less verbose output
    Outputs:
        Writes a CSV file for each record type found, in the same
        directory as the input export.xml. Reports each file written
        unless verbose has been set to False.
    """
    def __init__(self, path, verbose=VERBOSE):
        self.in_path = path
        self.verbose = verbose
        self.directory = os.path.abspath(os.path.split(path)[0])
        with open(path) as f:
            self.report('Reading data from %s . . . ' % path, end='')
            self.data = ElementTree.parse(f)
            self.report('done')
        self.root = self.data._root
        self.nodes = list(self.root)
        self.n_nodes = len(self.nodes)
        self.abbreviate_types()
        self.collect_stats()

    def report(self, msg, end='\n'):
        if self.verbose:
            print(msg, end=end)
            sys.stdout.flush()

    def count_tags_and_fields(self):
        self.tags = Counter()
        self.fields = Counter()
        for record in self.nodes:
            self.tags[record.tag] += 1
            for k in record.keys():
                self.fields[k] += 1

    def count_record_types(self):
        """
        Counts occurrences of each type of (conceptual) "record" in the data.
        In the case of nodes of type 'Record', this counts the number of
        occurrences of each 'type' or record in self.record_types.
        In the case of nodes of type 'ActivitySummary' and 'Workout',
        it just counts those in self.other_types.
        The slightly different handling reflects the fact that 'Record'
        nodes come in a variety of different subtypes that we want to write
        to different data files, whereas (for now) we are going to write
        all Workout entries to a single file, and all ActivitySummary
        entries to another single file.
        """
        self.record_types = Counter()
        self.other_types = Counter()
        for record in self.nodes:
            if record.tag == 'Record':
                self.record_types[record.attrib['type']] += 1
            elif record.tag in ('ActivitySummary', 'Workout'):
                self.other_types[record.tag] += 1
            elif record.tag in ('Export', 'Me'):
                pass
            else:
                self.report('Unexpected node of type %s.' % record.tag)

    def collect_stats(self):
        self.count_record_types()
        self.count_tags_and_fields()

    def open_for_writing(self):
        self.handles = {}
        self.paths = []
        for kind in (list(self.record_types) + list(self.other_types)):
            path = os.path.join(self.directory, '%s.csv' % abbreviate(kind))
            f = open(path, 'w')
            headerType = (kind if kind in ('Workout', 'ActivitySummary')
                               else 'Record')
            f.write(','.join(FIELDS[headerType].keys()) + '\n')
            self.handles[kind] = f
            self.report('Opening %s for writing' % path)

    def abbreviate_types(self):
        """
        Shorten types by removing common boilerplate text.
        """
        for node in self.nodes:
            if node.tag == 'Record':
                if 'type' in node.attrib:
                    node.attrib['type'] = abbreviate(node.attrib['type'])

    def write_records(self):
        kinds = FIELDS.keys()
        for node in self.nodes:
            if node.tag in kinds:
                attributes = node.attrib
                kind = attributes['type'] if node.tag == 'Record' else node.tag
                values = [format_value(attributes.get(field), datatype)
                          for (field, datatype) in FIELDS[node.tag].items()]
                line = ','.join(values) + '\n'
                self.handles[kind].write(line)

    def close_files(self):
        for (kind, f) in self.handles.items():
            f.close()
            self.report('Written %s data.' % abbreviate(kind))

    def extract(self):
        self.open_for_writing()
        self.write_records()
        self.close_files()

    def report_stats(self):
        print('\nTags:\n%s\n' % format_freqs(self.tags))
        print('Fields:\n%s\n' % format_freqs(self.fields))
        print('Record types:\n%s\n' % format_freqs(self.record_types))

# %%
data = HealthDataExtractor(path='raw_health_export.xml')
data.report_stats()
data.extract()
# Out:
# Reading data from raw_health_export.xml . . . done
# Unexpected node of type ExportDate.
#
# Tags:
# ActivitySummary: 900
# ExportDate: 1
# Me: 1
# Record: 2795078
# Workout: 1387
#
# Fields:
# HKCharacteristicTypeIdentifierBiologicalSex: 1
# HKCharacteristicTypeIdentifierBloodType: 1
# HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse: 1
# HKCharacteristicTypeIdentifierDateOfBirth: 1
# HKCharacteristicTypeIdentifierFitzpatrickSkinType: 1
# activeEnergyBurned: 900
# activeEnergyBurnedGoal: 900
# activeEnergyBurnedUnit: 900
# appleExerciseTime: 900
# appleExerciseTimeGoal: 900
# appleMoveTime: 900
# appleMoveTimeGoal: 900
# appleStandHours: 900
# appleStandHoursGoal: 900
# creationDate: 2796465
# dateComponents: 900
# device: 2583875
# duration: 1387
# durationUnit: 1387
# endDate: 2796465
# sourceName: 2796465
# sourceVersion: 2696886
# startDate: 2796465
# type: 2795078
# unit: 2770121
# value: 2794900
# workoutActivityType: 1387
#
# Record types:
# ActiveEnergyBurned: 853486
# AppleExerciseTime: 73715
# AppleStandHour: 24515
# AppleStandTime: 45524
# AppleWalkingSteadiness: 73
# AudioExposureEvent: 250
# BasalEnergyBurned: 297838
# BodyMass: 3747
# BodyMassIndex: 3344
# DietaryEnergyConsumed: 6
# DietaryWater: 1
# DistanceCycling: 49
# DistanceSwimming: 39
# DistanceWalkingRunning: 291024
# EnvironmentalAudioExposure: 40515
# EnvironmentalSoundReduction: 632
# FlightsClimbed: 44125
# HKDataTypeSleepDurationGoal: 1
# HandwashingEvent: 86
# HeadphoneAudioExposure: 18757
# HeadphoneAudioExposureEvent: 13
# HeartRate: 411634
# HeartRateRecoveryOneMinute: 67
# HeartRateVariabilitySDNN: 6904
# Height: 2
# HighHeartRateEvent: 5
# LowHeartRateEvent: 4
# MindfulSession: 84
# NumberOfTimesFallen: 1
# OxygenSaturation: 13319
# RespiratoryRate: 23939
# RestingHeartRate: 894
# RunningGroundContactTime: 28981
# RunningPower: 68738
# RunningSpeed: 80848
# RunningStrideLength: 31271
# RunningVerticalOscillation: 33382
# SixMinuteWalkTestDistance: 104
# StairAscentSpeed: 9527
# StairDescentSpeed: 14880
# StepCount: 249130
# SwimmingStrokeCount: 39
# VO2Max: 739
# WalkingAsymmetryPercentage: 9659
# WalkingDoubleSupportPercentage: 30273
# WalkingHeartRateAverage: 877
# WalkingSpeed: 41016
# WalkingStepLength: 41021
#
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\DietaryWater.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\BodyMassIndex.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\Height.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\BodyMass.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HeartRate.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\OxygenSaturation.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RespiratoryRate.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\StepCount.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\DistanceWalkingRunning.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\BasalEnergyBurned.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\ActiveEnergyBurned.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\FlightsClimbed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\DietaryEnergyConsumed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\NumberOfTimesFallen.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\AppleExerciseTime.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\DistanceCycling.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\DistanceSwimming.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\SwimmingStrokeCount.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RestingHeartRate.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\VO2Max.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\WalkingHeartRateAverage.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\EnvironmentalAudioExposure.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HeadphoneAudioExposure.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\WalkingDoubleSupportPercentage.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\SixMinuteWalkTestDistance.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\AppleStandTime.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\WalkingSpeed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\WalkingStepLength.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\WalkingAsymmetryPercentage.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\StairAscentSpeed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\StairDescentSpeed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HKDataTypeSleepDurationGoal.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\AppleWalkingSteadiness.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RunningStrideLength.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RunningVerticalOscillation.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RunningGroundContactTime.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HeartRateRecoveryOneMinute.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RunningPower.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\EnvironmentalSoundReduction.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\RunningSpeed.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\AppleStandHour.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\MindfulSession.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HighHeartRateEvent.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\LowHeartRateEvent.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\AudioExposureEvent.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HeadphoneAudioExposureEvent.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HandwashingEvent.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\HeartRateVariabilitySDNN.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\Workout.csv for writing
# Opening c:\Users\mathi\Downloads\Rob Mulla Kaggle Comp\ActivitySummary.csv for writing
# Written DietaryWater data.
# Written BodyMassIndex data.
# Written Height data.
# Written BodyMass data.
# Written HeartRate data.
# Written OxygenSaturation data.
# Written RespiratoryRate data.
# Written StepCount data.
# Written DistanceWalkingRunning data.
# Written BasalEnergyBurned data.
# Written ActiveEnergyBurned data.
# Written FlightsClimbed data.
# Written DietaryEnergyConsumed data.
# Written NumberOfTimesFallen data.
# Written AppleExerciseTime data.
# Written DistanceCycling data.
# Written DistanceSwimming data.
# Written SwimmingStrokeCount data.
# Written RestingHeartRate data.
# Written VO2Max data.
# Written WalkingHeartRateAverage data.
# Written EnvironmentalAudioExposure data.
# Written HeadphoneAudioExposure data.
# Written WalkingDoubleSupportPercentage data.
# Written SixMinuteWalkTestDistance data.
# Written AppleStandTime data.
# Written WalkingSpeed data.
# Written WalkingStepLength data.
# Written WalkingAsymmetryPercentage data.
# Written StairAscentSpeed data.
# Written StairDescentSpeed data.
# Written HKDataTypeSleepDurationGoal data.
# Written AppleWalkingSteadiness data.
# Written RunningStrideLength data.
# Written RunningVerticalOscillation data.
# Written RunningGroundContactTime data.
# Written HeartRateRecoveryOneMinute data.
# Written RunningPower data.
# Written EnvironmentalSoundReduction data.
# Written RunningSpeed data.
# Written AppleStandHour data.
# Written MindfulSession data.
# Written HighHeartRateEvent data.
# Written LowHeartRateEvent data.
# Written AudioExposureEvent data.
# Written HeadphoneAudioExposureEvent data.
# Written HandwashingEvent data.
# Written HeartRateVariabilitySDNN data.
# Written Workout data.
# Written ActivitySummary data.

# %% [markdown]
# #### Reading the CSV files

# %%
train_detailed = (pd.read_csv("train_detailed.csv",
                              parse_dates=['startDate', 'endDate', 'creationDate'])
                  .assign(startDate = lambda x: x.startDate.dt.tz_localize(None),
                          endDate = lambda x: x.endDate.dt.tz_localize(None),
                          creationDate = lambda x: x.creationDate.dt.tz_localize(None))
                  )

# %%
train = pd.read_csv("train.csv", parse_dates=['date'])
test = pd.read_csv("test.csv", parse_dates=['date'])

# %% [markdown]
# Gotta read in the huge number of csv files from the XML... The aim is to left-join all data on the train dataset and then proceed with modelling.
#
# 1. Read in every file, inspect what I want to do with the data (how to aggregate to daily)
# 2. Aggregate to daily
# 3. Left-join

# %%
active_energy = (pd.read_csv("XML/ActiveEnergyBurned.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(active_energy=('value', np.sum))
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

active_energy.head(5)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_16688\438852256.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#         date  active_energy
# 0 2015-02-19          487.0
# 1 2015-02-20         1789.0
# 2 2015-02-21         1185.0
# 3 2015-02-22         2173.0
# 4 2015-02-23          903.0

# %%
exercise_time = (pd.read_csv("XML/AppleExerciseTime.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(exercise_minutes=('value', np.sum))
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

exercise_time.head(5)
# Out:
#         date  exercise_minutes
# 0 2020-09-25                 1
# 1 2020-09-26               105
# 2 2020-09-27                59
# 3 2020-09-28               118
# 4 2020-09-29                25

# %%
stand_hour = (pd.read_csv("XML/AppleStandHour.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .value_counts(['date', 'value'])
                .reset_index(name='count')
                .sort_values('date')
                .pivot(index='date', values='count', columns='value')
                .reset_index()
                .rename_axis(None, axis=1)
                .assign(date = lambda x: pd.to_datetime(x['date']))
                )

stand_hour.head(5)
# Out:
#         date  HKCategoryValueAppleStandHourIdle  \
# 0 2020-09-25                                NaN
# 1 2020-09-26                                6.0
# 2 2020-09-27                               11.0
# 3 2020-09-28                                7.0
# 4 2020-09-29                               11.0
#
#    HKCategoryValueAppleStandHourStood
# 0                                 4.0
# 1                                18.0
# 2                                13.0
# 3                                24.0
# 4                                12.0

# %%
stand_minutes = (pd.read_csv("XML/AppleStandTime.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(minutes_stood=('value', np.sum))
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

stand_minutes.head(5)
# Out:
#         date  minutes_stood
# 0 2020-09-25             26
# 1 2020-09-26            241
# 2 2020-09-27            119
# 3 2020-09-28            164
# 4 2020-09-29             56

# %%
audio_exposure_event = (pd.read_csv("XML/AudioExposureEvent.csv",
                                    parse_dates=['startDate', 'endDate', 'creationDate'])
                        .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                                endDate=lambda x: x.endDate.dt.tz_localize(None),
                                creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                        .assign(date=lambda x: x['startDate'].dt.date)
                        .value_counts(['date', 'value'])
                        .reset_index(name='count')
                        .sort_values('date')
                        .pivot(index='date', values='count', columns='value')
                        .reset_index()
                        .rename_axis(None, axis=1)
                        .assign(date=lambda x: pd.to_datetime(x['date']))
                        )

audio_exposure_event.head(5)
# Out:
#         date  HKCategoryValueEnvironmentalAudioExposureEventMomentaryLimit
# 0 2020-09-26                                                  1
# 1 2020-10-30                                                  3
# 2 2020-11-26                                                  1
# 3 2021-02-17                                                  1
# 4 2021-02-18                                                  2

# %%
basal_energy = (pd.read_csv("XML/BasalEnergyBurned.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(basal_energy=('value', np.sum))
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

basal_energy.head(5)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_16688\3936777324.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#         date  basal_energy
# 0 2012-04-20        1913.0
# 1 2012-04-21        1913.0
# 2 2012-04-22        1913.0
# 3 2012-04-23        1913.0
# 4 2012-04-24        1913.0

# %%
body_mass = (pd.read_csv("XML/BodyMass.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(body_mass=('value', np.mean))       
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

body_mass.head(5)
# Out:
#         date  body_mass
# 0 2012-04-20    188.799
# 1 2012-04-21    188.799
# 2 2012-04-22    188.799
# 3 2012-04-23    188.799
# 4 2012-04-24    188.799

# %%
body_mass_index = (pd.read_csv("XML/BodyMassIndex.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(body_mass_index=('value', np.mean))       
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

body_mass_index.head(5)
# Out:
#         date  body_mass_index
# 0 2012-04-20          23.5981
# 1 2012-04-21          23.5981
# 2 2012-04-22          23.5981
# 3 2012-04-23          23.5981
# 4 2012-04-24          23.5981

# %%
distance_walking_running = (pd.read_csv("XML/DistanceWalkingRunning.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(distance_walking_running=('value', np.sum))       
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

distance_walking_running.head(5)
# Out:
#         date  distance_walking_running
# 0 2015-02-18                  0.019188
# 1 2015-02-19                  1.311870
# 2 2015-02-20                  7.167910
# 3 2015-02-21                  3.823910
# 4 2015-02-22                  8.195990

# %%
env_audio_exposure = (pd.read_csv("XML/EnvironmentalAudioExposure.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(env_audio_exposure_min=('value', np.min),
                     env_audio_exposure_mean=('value', np.mean),
                     env_audio_exposure_median=('value', np.median),
                     env_audio_exposure_max=('value', np.max))       
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

env_audio_exposure.head(5)
# Out:
#         date  env_audio_exposure_min  env_audio_exposure_mean  \
# 0 2020-09-26                 40.5313                71.283803
# 1 2020-09-27                 44.8399                61.727400
# 2 2020-09-28                 44.2695                59.369372
# 3 2020-09-29                 48.3998                61.768209
# 4 2020-09-30                 50.3467                62.081132
#
#    env_audio_exposure_median  env_audio_exposure_max
# 0                   71.50180                 91.9333
# 1                   63.58785                 81.5414
# 2                   59.74100                 78.0796
# 3                   62.67415                 77.3387
# 4                   62.58810                 85.8944

# %%
flights_climbed = (pd.read_csv("XML/FlightsClimbed.csv",
                            parse_dates=['startDate', 'endDate', 'creationDate'])
                .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                        endDate=lambda x: x.endDate.dt.tz_localize(None),
                        creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                .assign(date=lambda x: x['startDate'].dt.date)
                .groupby('date', as_index=False)
                .agg(flights_climbed=('value', np.sum))       
                .assign(date=lambda x: pd.to_datetime(x['date']))
                )

flights_climbed.head(5)
# Out:
#         date  flights_climbed
# 0 2015-04-19                8
# 1 2015-04-20                9
# 2 2015-04-21                5
# 3 2015-04-22               15
# 4 2015-04-23               23

# %%
headphone_exposure = (pd.read_csv("XML/HeadphoneAudioExposure.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(headphone_audio_exposure_min=('value', np.min),
                           headphone_audio_exposure_mean=('value', np.mean),
                           headphone_audio_exposure_median=('value', np.median),
                           headphone_audio_exposure_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

headphone_exposure.head(5)
# Out:
#         date  headphone_audio_exposure_min  headphone_audio_exposure_mean  \
# 0 2020-06-10                       3.29836                      44.117424
# 1 2020-06-11                      22.32960                      56.697617
# 2 2020-06-15                      29.59910                      77.771241
# 3 2020-06-22                      44.64830                      59.629152
# 4 2020-06-23                      25.58600                      47.822500
#
#    headphone_audio_exposure_median  headphone_audio_exposure_max
# 0                          46.4057                       71.4634
# 1                          63.4311                       69.2495
# 2                          84.2212                       86.5065
# 3                          57.0473                       80.0172
# 4                          51.1487                       72.8219

# %%
heartrate = (pd.read_csv("XML/HeartRate.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(heartrate_min=('value', np.min),
                           heartrate_mean=('value', np.mean),
                           heartrate_median=('value', np.median),
                           heartrate_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

heartrate.head(5)
# Out:
# C:\Users\mathi\AppData\Local\Temp\ipykernel_16688\3038444347.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#         date  heartrate_min  heartrate_mean  heartrate_median  heartrate_max
# 0 2015-04-20           73.0      115.602243             114.0          202.0
# 1 2015-04-21           22.0      130.741510             135.0          201.0
# 2 2015-04-22           61.0      122.718360             123.0          158.0
# 3 2015-04-23           77.0      155.503007             159.0          181.0
# 4 2015-04-24           73.0      125.893857             124.0          166.0

# %%
heartrate_variability = (pd.read_csv("XML/HeartRateVariabilitySDNN.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(heartrate_var_min=('value', np.min),
                           heartrate_var_mean=('value', np.mean),
                           heartrate_var_median=('value', np.median),
                           heartrate_var_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

heartrate_variability.head(5)
# Out:
#         date  heartrate_var_min  heartrate_var_mean  heartrate_var_median  \
# 0 2020-09-25            59.7688           78.674450              78.67445
# 1 2020-09-26            45.8612           56.330725              53.94875
# 2 2020-09-27            40.6202           61.245689              52.76360
# 3 2020-09-28            44.4480           72.409940              46.99470
# 4 2020-09-29            37.7384           50.930600              53.67525
#
#    heartrate_var_max
# 0            97.5801
# 1            71.5642
# 2           100.4600
# 3           144.1750
# 4            63.6494

# %%
oxygen_saturation = (pd.read_csv("XML/OxygenSaturation.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(oxygen_saturation_min=('value', np.min),
                           oxygen_saturation_mean=('value', np.mean),
                           oxygen_saturation_median=('value', np.median),
                           oxygen_saturation_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

oxygen_saturation.head(5)
# Out:
#         date  oxygen_saturation_min  oxygen_saturation_mean  \
# 0 2020-09-25                   0.99                0.990000
# 1 2020-09-26                   0.94                0.970667
# 2 2020-09-27                   0.94                0.974737
# 3 2020-09-28                   0.95                0.970000
# 4 2020-09-29                   0.95                0.969375
#
#    oxygen_saturation_median  oxygen_saturation_max
# 0                      0.99                   0.99
# 1                      0.96                   1.00
# 2                      0.97                   1.00
# 3                      0.97                   1.00
# 4                      0.97                   0.99

# %%
respiratory_rate = (pd.read_csv("XML/RespiratoryRate.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(respiratory_rate_min=('value', np.min),
                           respiratory_rate_mean=('value', np.mean),
                           respiratory_rate_median=('value', np.median),
                           respiratory_rate_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

respiratory_rate.head(5)
# Out:
#         date  respiratory_rate_min  respiratory_rate_mean  \
# 0 2021-10-25                  17.0              20.750000
# 1 2021-10-26                  14.0              16.855769
# 2 2021-10-27                  13.5              16.981818
# 3 2021-10-28                  15.0              17.209302
# 4 2021-10-29                  13.5              16.385965
#
#    respiratory_rate_median  respiratory_rate_max
# 0                    20.75                  24.5
# 1                    17.00                  22.5
# 2                    16.50                  25.0
# 3                    16.50                  24.5
# 4                    16.00                  23.0

# %%
resting_heartrate = (pd.read_csv("XML/RestingHeartRate.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(resting_heartrate = ('value', np.mean))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

resting_heartrate.head(5)
# Out:
#         date  resting_heartrate
# 0 2020-09-25               56.0
# 1 2020-09-26               56.0
# 2 2020-09-27               53.0
# 3 2020-09-28               54.0
# 4 2020-09-29               52.0

# %%
stair_ascent_speed = (pd.read_csv("XML/StairAscentSpeed.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(stair_ascent_speed_min=('value', np.min),
                           stair_ascent_speed_mean=('value', np.mean),
                           stair_ascent_speed_median=('value', np.median),
                           stair_ascent_speed_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

stair_ascent_speed.head(5)
# Out:
#         date  stair_ascent_speed_min  stair_ascent_speed_mean  \
# 0 2020-09-25                1.172390                 1.371140
# 1 2020-09-26                0.754373                 1.236808
# 2 2020-09-27                1.003990                 1.420550
# 3 2020-09-28                0.708712                 0.968418
# 4 2020-09-29                1.055190                 1.380167
#
#    stair_ascent_speed_median  stair_ascent_speed_max
# 0                   1.371140                 1.56989
# 1                   1.090450                 2.17955
# 2                   1.420550                 1.83711
# 3                   0.905707                 1.99061
# 4                   1.524110                 1.56120

# %%
stair_descent_speed = (pd.read_csv("XML/StairDescentSpeed.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(stair_descent_speed_min=('value', np.min),
                           stair_descent_speed_mean=('value', np.mean),
                           stair_descent_speed_median=('value', np.median),
                           stair_descent_speed_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

stair_descent_speed.head(5)
# Out:
#         date  stair_descent_speed_min  stair_descent_speed_mean  \
# 0 2020-09-26                 1.454820                  1.767678
# 1 2020-09-27                 0.689655                  1.099932
# 2 2020-09-28                 0.670295                  1.149277
# 3 2020-09-29                 1.616140                  1.945814
# 4 2020-09-30                 1.857610                  1.857610
#
#    stair_descent_speed_median  stair_descent_speed_max
# 0                    1.721255                  2.17338
# 1                    0.832439                  2.05139
# 2                    1.058170                  2.24115
# 3                    1.863570                  2.52648
# 4                    1.857610                  1.85761

# %%
step_count = (pd.read_csv("XML/StepCount.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(step_count = ('value', np.sum))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

step_count.head(5)
# Out:
#         date  step_count
# 0 2015-02-18          44
# 1 2015-02-19        2669
# 2 2015-02-20       14552
# 3 2015-02-21        7769
# 4 2015-02-22       16675

# %%
vo2_max = (pd.read_csv("XML/VO2Max.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(vo2_max = ('value', np.mean))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

vo2_max.head(5)
# Out:
#         date  vo2_max
# 0 2020-09-30    46.64
# 1 2020-10-01    42.94
# 2 2020-10-05    42.94
# 3 2020-10-06    42.99
# 4 2020-10-09    43.72

# %%
walking_asymmetry = (pd.read_csv("XML/WalkingAsymmetryPercentage.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(walking_asymmetry_min=('value', np.min),
                           walking_asymmetry_mean=('value', np.mean),
                           walking_asymmetry_median=('value', np.median),
                           walking_asymmetry_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

walking_asymmetry.head(5)
# Out:
#         date  walking_asymmetry_min  walking_asymmetry_mean  \
# 0 2020-01-10                    0.0                0.000000
# 1 2020-01-11                    0.0                0.003043
# 2 2020-01-12                    0.0                0.010000
# 3 2020-02-10                    0.0                0.025000
# 4 2020-02-11                    0.0                0.000000
#
#    walking_asymmetry_median  walking_asymmetry_max
# 0                       0.0                   0.00
# 1                       0.0                   0.07
# 2                       0.0                   0.07
# 3                       0.0                   0.10
# 4                       0.0                   0.00

# %%
walking_doublesupport = (pd.read_csv("XML/WalkingDoubleSupportPercentage.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(walking_support_min=('value', np.min),
                           walking_support_mean=('value', np.mean),
                           walking_support_median=('value', np.median),
                           walking_support_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

walking_doublesupport.head(5)
# Out:
#         date  walking_support_min  walking_support_mean  \
# 0 2020-09-25                0.293              0.293000
# 1 2020-09-26                0.245              0.294344
# 2 2020-09-27                0.261              0.292441
# 3 2020-09-28                0.180              0.287185
# 4 2020-09-29                0.278              0.300857
#
#    walking_support_median  walking_support_max
# 0                   0.293                0.293
# 1                   0.294                0.338
# 2                   0.291                0.359
# 3                   0.287                0.344
# 4                   0.303                0.325

# %%
walking_heartrate = (pd.read_csv("XML/WalkingHeartRateAverage.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(walking_heartrate_mean=('value', np.mean))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

walking_heartrate.head(5)
# Out:
#         date  walking_heartrate_mean
# 0 2020-09-26                   125.0
# 1 2020-09-27                   100.0
# 2 2020-09-28                    93.0
# 3 2020-09-29                   100.5
# 4 2020-09-30                   107.0

# %%
walking_speed = (pd.read_csv("XML/WalkingSpeed.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(walking_speed_min=('value', np.min),
                           walking_speed_mean=('value', np.mean),
                           walking_speed_median=('value', np.median),
                           walking_speed_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

walking_speed.head(5)
# Out:
#         date  walking_speed_min  walking_speed_mean  walking_speed_median  \
# 0 2020-09-25            2.34878            2.348780               2.34878
# 1 2020-09-26            1.67770            2.772081               2.77380
# 2 2020-09-27            1.83429            2.867007               2.86328
# 3 2020-09-28            1.78955            2.971340               2.88565
# 4 2020-09-29            2.25931            2.614021               2.55011
#
#    walking_speed_max
# 0            2.34878
# 1            3.98175
# 2            3.53436
# 3            5.01074
# 4            2.93039

# %%
walking_steplength = (pd.read_csv("XML/WalkingStepLength.csv",
                                  parse_dates=['startDate', 'endDate', 'creationDate'])
                      .assign(startDate=lambda x: x.startDate.dt.tz_localize(None),
                              endDate=lambda x: x.endDate.dt.tz_localize(None),
                              creationDate=lambda x: x.creationDate.dt.tz_localize(None))
                      .assign(date=lambda x: x['startDate'].dt.date)
                      .groupby('date', as_index=False)
                      .agg(walking_steplength_min=('value', np.min),
                           walking_steplength_mean=('value', np.mean),
                           walking_steplength_median=('value', np.median),
                           walking_steplength_max=('value', np.max))
                      .assign(date=lambda x: pd.to_datetime(x['date']))
                      )

walking_steplength.head(5)
# Out:
#         date  walking_steplength_min  walking_steplength_mean  \
# 0 2020-09-25                 23.2283                23.228300
# 1 2020-09-26                 20.0787                28.073909
# 2 2020-09-27                 18.8976                29.291362
# 3 2020-09-28                 18.8976                29.636615
# 4 2020-09-29                 25.9843                28.177771
#
#    walking_steplength_median  walking_steplength_max
# 0                   23.22830                 23.2283
# 1                   29.52760                 35.8268
# 2                   29.72445                 35.4331
# 3                   28.74020                 53.1496
# 4                   27.55910                 30.7087

# %% [markdown]
# Concatenate train and test just for the quick left-join:

# %%
pd.concat([train.assign(id='train'), test.assign(id='test')])
# Out:
#           date  sleep_hours     id
# 0   2015-02-19     6.400000  train
# 1   2015-02-20     7.583333  train
# 2   2015-02-21     6.350000  train
# 3   2015-02-22     6.500000  train
# 4   2015-02-23     8.916667  train
# ..         ...          ...    ...
# 414 2023-03-12     1.000000   test
# 415 2023-03-13     1.000000   test
# 416 2023-03-14     1.000000   test
# 417 2023-03-15     1.000000   test
# 418 2023-03-16     1.000000   test
#
# [2773 rows x 3 columns]

# %%
data_prepped = (pd.concat([train.assign(id='train'), test.assign(id='test')])
 .merge(active_energy, how='left', on='date')
 .merge(exercise_time, how='left', on='date')
 .merge(stand_hour, how='left', on='date')
 .merge(audio_exposure_event, how='left', on='date')
 .merge(stand_minutes, how='left', on='date')
 .merge(basal_energy, how='left', on='date')
 .merge(body_mass, how='left', on='date')
 .merge(body_mass_index, how='left', on='date')
 .merge(distance_walking_running, how='left', on='date')
 .merge(env_audio_exposure, how='left', on='date')
 .merge(flights_climbed, how='left', on='date')
 .merge(headphone_exposure, how='left', on='date')
 .merge(heartrate, how='left', on='date')
 .merge(heartrate_variability, how='left', on='date')
 .merge(oxygen_saturation, how='left', on='date')
 .merge(respiratory_rate, how='left', on='date')
 .merge(resting_heartrate, how='left', on='date')
 .merge(stair_ascent_speed, how='left', on='date')
 .merge(stair_descent_speed, how='left', on='date')
 .merge(step_count, how='left', on='date')
 .merge(vo2_max, how='left', on='date')
 .merge(walking_asymmetry, how='left', on='date')
 .merge(walking_doublesupport, how='left', on='date')
 .merge(walking_heartrate, how='left', on='date')
 .merge(walking_speed, how='left', on='date')
 .merge(walking_steplength, how='left', on='date')
 .copy()
 )

data_prepped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2773 entries, 0 to 2772
# Data columns (total 66 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   date                                                          2773 non-null   datetime64[ns]
#  1   sleep_hours                                                   2773 non-null   float64
#  2   id                                                            2773 non-null   object
#  3   active_energy                                                 1472 non-null   float64
#  4   exercise_minutes                                              871 non-null    float64
#  5   HKCategoryValueAppleStandHourIdle                             870 non-null    float64
#  6   HKCategoryValueAppleStandHourStood                            871 non-null    float64
#  7   HKCategoryValueEnvironmentalAudioExposureEventMomentaryLimit  149 non-null    float64
#  8   minutes_stood                                                 871 non-null    float64
#  9   basal_energy                                                  2773 non-null   float64
#  10  body_mass                                                     2281 non-null   float64
#  11  body_mass_index                                               1903 non-null   float64
#  12  distance_walking_running                                      2773 non-null   float64
#  13  env_audio_exposure_min                                        871 non-null    float64
#  14  env_audio_exposure_mean                                       871 non-null    float64
#  15  env_audio_exposure_median                                     871 non-null    float64
#  16  env_audio_exposure_max                                        871 non-null    float64
#  17  flights_climbed                                               2740 non-null   float64
#  18  headphone_audio_exposure_min                                  897 non-null    float64
#  19  headphone_audio_exposure_mean                                 897 non-null    float64
#  20  headphone_audio_exposure_median                               897 non-null    float64
#  21  headphone_audio_exposure_max                                  897 non-null    float64
#  22  heartrate_min                                                 877 non-null    float64
#  23  heartrate_mean                                                877 non-null    float64
#  24  heartrate_median                                              877 non-null    float64
#  25  heartrate_max                                                 877 non-null    float64
#  26  heartrate_var_min                                             870 non-null    float64
#  27  heartrate_var_mean                                            870 non-null    float64
#  28  heartrate_var_median                                          870 non-null    float64
#  29  heartrate_var_max                                             870 non-null    float64
#  30  oxygen_saturation_min                                         871 non-null    float64
#  31  oxygen_saturation_mean                                        871 non-null    float64
#  32  oxygen_saturation_median                                      871 non-null    float64
#  33  oxygen_saturation_max                                         871 non-null    float64
#  34  respiratory_rate_min                                          482 non-null    float64
#  35  respiratory_rate_mean                                         482 non-null    float64
#  36  respiratory_rate_median                                       482 non-null    float64
#  37  respiratory_rate_max                                          482 non-null    float64
#  38  resting_heartrate                                             870 non-null    float64
#  39  stair_ascent_speed_min                                        860 non-null    float64
#  40  stair_ascent_speed_mean                                       860 non-null    float64
#  41  stair_ascent_speed_median                                     860 non-null    float64
#  42  stair_ascent_speed_max                                        860 non-null    float64
#  43  stair_descent_speed_min                                       864 non-null    float64
#  44  stair_descent_speed_mean                                      864 non-null    float64
#  45  stair_descent_speed_median                                    864 non-null    float64
#  46  stair_descent_speed_max                                       864 non-null    float64
#  47  step_count                                                    2773 non-null   int64
#  48  vo2_max                                                       708 non-null    float64
#  49  walking_asymmetry_min                                         804 non-null    float64
#  50  walking_asymmetry_mean                                        804 non-null    float64
#  51  walking_asymmetry_median                                      804 non-null    float64
#  52  walking_asymmetry_max                                         804 non-null    float64
#  53  walking_support_min                                           870 non-null    float64
#  54  walking_support_mean                                          870 non-null    float64
#  55  walking_support_median                                        870 non-null    float64
#  56  walking_support_max                                           870 non-null    float64
#  57  walking_heartrate_mean                                        855 non-null    float64
#  58  walking_speed_min                                             870 non-null    float64
#  59  walking_speed_mean                                            870 non-null    float64
#  60  walking_speed_median                                          870 non-null    float64
#  61  walking_speed_max                                             870 non-null    float64
#  62  walking_steplength_min                                        870 non-null    float64
#  63  walking_steplength_mean                                       870 non-null    float64
#  64  walking_steplength_median                                     870 non-null    float64
#  65  walking_steplength_max                                        870 non-null    float64
# dtypes: datetime64[ns](1), float64(63), int64(1), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# Separating back into train and test:

# %%
train = (data_prepped
 .query('id == "train"')
 .drop('id', axis=1)
 .reset_index(drop=True)
 )

test = (data_prepped
 .query('id == "test"')
 .drop('id', axis=1)
 .reset_index(drop=True)
 )

# %%
test
# Out:
#           date  sleep_hours  active_energy  exercise_minutes  \
# 0   2022-01-01          1.0       1802.449             104.0
# 1   2022-01-02          1.0       2982.172             177.0
# 2   2022-01-03          1.0       1941.497             115.0
# 3   2022-01-04          1.0       1566.851              96.0
# 4   2022-01-05          1.0       2579.864             156.0
# ..         ...          ...            ...               ...
# 414 2023-03-12          1.0        485.440              20.0
# 415 2023-03-13          1.0       1669.080              85.0
# 416 2023-03-14          1.0       2269.436             133.0
# 417 2023-03-15          1.0       1648.959              88.0
# 418 2023-03-16          1.0       1712.744              90.0
#
#      HKCategoryValueAppleStandHourIdle  HKCategoryValueAppleStandHourStood  \
# 0                                  6.0                                33.0
# 1                                 11.0                                24.0
# 2                                  9.0                                30.0
# 3                                  8.0                                19.0
# 4                                 14.0                                22.0
# ..                                 ...                                 ...
# 414                                9.0                                14.0
# 415                               16.0                                12.0
# 416                               12.0                                18.0
# 417                               10.0                                23.0
# 418                               13.0                                15.0
#
#      HKCategoryValueEnvironmentalAudioExposureEventMomentaryLimit  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 414                                                NaN
# 415                                                NaN
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
#
#      minutes_stood  basal_energy  body_mass  body_mass_index  \
# 0            128.0      2089.326        NaN              NaN
# 1            132.0      2025.210      192.8              NaN
# 2            123.0      2070.001      193.4              NaN
# 3             89.0      1950.298      191.0              NaN
# 4            123.0      2030.691      188.2              NaN
# ..             ...           ...        ...              ...
# 414          101.0      2171.837        NaN              NaN
# 415           80.0      2208.939      201.8              NaN
# 416          108.0      2183.173        NaN              NaN
# 417           77.0      2137.165        NaN              NaN
# 418           62.0      2256.459        NaN              NaN
#
#      distance_walking_running  env_audio_exposure_min  \
# 0                   16.686231                 46.0920
# 1                   27.026786                 39.5644
# 2                   17.661256                 42.4967
# 3                   14.542260                 41.4022
# 4                   23.285167                 47.1578
# ..                        ...                     ...
# 414                  3.199846                 41.4948
# 415                 13.882898                 46.3354
# 416                 20.237776                 44.9641
# 417                 14.429490                 43.5476
# 418                 13.610358                 43.6083
#
#      env_audio_exposure_mean  env_audio_exposure_median  \
# 0                  65.053287                   67.01795
# 1                  62.348590                   65.35100
# 2                  60.688543                   61.20610
# 3                  61.143140                   61.96725
# 4                  61.075746                   60.99650
# ..                       ...                        ...
# 414                59.897020                   56.87430
# 415                57.339388                   54.16800
# 416                58.649826                   59.58350
# 417                64.606065                   64.06290
# 418                57.778634                   53.99320
#
#      env_audio_exposure_max  flights_climbed  headphone_audio_exposure_min  \
# 0                   78.8768             43.0                        0.0000
# 1                   80.7179             71.0                        0.0000
# 2                   84.3081             35.0                       47.2848
# 3                   84.1344             45.0                        0.0000
# 4                   76.0110             60.0                       75.8013
# ..                      ...              ...                           ...
# 414                 83.5157             32.0                       66.3341
# 415                 72.1421             41.0                       55.8954
# 416                 71.8246             71.0                        0.0000
# 417                 85.4633             45.0                       31.7297
# 418                 78.9452             61.0                       55.1001
#
#      headphone_audio_exposure_mean  headphone_audio_exposure_median  \
# 0                        56.030966                         67.87115
# 1                        70.113413                         78.77610
# 2                        72.966550                         78.24450
# 3                        35.978019                         19.87010
# 4                        81.267738                         80.24400
# ..                             ...                              ...
# 414                      72.787475                         69.50640
# 415                      71.060029                         76.62900
# 416                      60.994986                         70.25410
# 417                      71.229290                         78.93205
# 418                      71.774140                         68.56570
#
#      headphone_audio_exposure_max  heartrate_min  heartrate_mean  \
# 0                         88.6707           42.0       75.768965
# 1                         93.0875           47.0       75.117756
# 2                         89.8971           46.0       67.099667
# 3                         82.2624           41.0       66.317184
# 4                         88.1498           48.0       71.112040
# ..                            ...            ...             ...
# 414                       85.8030           45.0       62.919270
# 415                       79.0951           45.0      108.161167
# 416                       84.4533           49.0      140.239636
# 417                       85.5273           45.0      129.186419
# 418                       86.1129           48.0      113.961841
#
#      heartrate_median  heartrate_max  heartrate_var_min  heartrate_var_mean  \
# 0                67.0        169.000            49.9237           62.938750
# 1                65.0        167.903            27.7781           39.378067
# 2                60.0        175.177            36.0798           45.128400
# 3                58.0        173.000            50.4108           82.669000
# 4                61.0        176.093            26.4528           63.201460
# ..                ...            ...                ...                 ...
# 414              59.0        125.000            37.1588           57.368264
# 415              92.0        183.000            30.4413           53.282227
# 416             170.5        181.000            38.2061           58.561370
# 417             165.0        177.000            24.7969           51.061036
# 418              91.0        182.000            28.8036           53.928860
#
#      heartrate_var_median  heartrate_var_max  oxygen_saturation_min  \
# 0                63.02290            76.2496                   0.90
# 1                39.59940            50.8589                   0.94
# 2                43.79265            56.8485                   0.94
# 3                51.59520           146.0010                   0.96
# 4                61.39370           129.8100                   0.92
# ..                    ...                ...                    ...
# 414              51.18800           103.0970                   0.96
# 415              55.09480            70.1224                   0.92
# 416              54.50440           112.0390                   0.94
# 417              46.10700            86.1832                   0.95
# 418              51.28645            78.5868                   0.94
#
#      oxygen_saturation_mean  oxygen_saturation_median  oxygen_saturation_max  \
# 0                  0.967500                     0.980                   1.00
# 1                  0.969167                     0.965                   1.00
# 2                  0.972143                     0.975                   1.00
# 3                  0.978571                     0.980                   1.00
# 4                  0.966000                     0.970                   0.99
# ..                      ...                       ...                    ...
# 414                0.982353                     0.980                   1.00
# 415                0.962500                     0.960                   0.99
# 416                0.973333                     0.970                   1.00
# 417                0.973846                     0.970                   1.00
# 418                0.970000                     0.970                   0.99
#
#      respiratory_rate_min  respiratory_rate_mean  respiratory_rate_median  \
# 0                    16.0              18.220930                    18.00
# 1                    16.0              18.216216                    17.50
# 2                    15.5              18.420455                    17.75
# 3                    15.5              17.304878                    17.00
# 4                    15.0              17.285714                    17.00
# ..                    ...                    ...                      ...
# 414                  12.0              18.030000                    17.25
# 415                  15.0              17.091837                    17.00
# 416                  14.5              17.466667                    17.00
# 417                  14.0              17.444444                    16.50
# 418                  14.5              16.930233                    16.50
#
#      respiratory_rate_max  resting_heartrate  stair_ascent_speed_min  \
# 0                    25.0               53.0                0.710106
# 1                    27.5               53.0                0.767510
# 2                    25.0               55.0                0.812983
# 3                    22.5               52.0                0.826994
# 4                    23.0               52.0                0.968357
# ..                    ...                ...                     ...
# 414                  24.0               51.0                0.720210
# 415                  24.5               49.0                0.820322
# 416                  22.0               53.0                0.658285
# 417                  26.5               60.0                0.779132
# 418                  24.0               64.0                0.681594
#
#      stair_ascent_speed_mean  stair_ascent_speed_median  \
# 0                   1.083547                   1.186330
# 1                   1.158289                   1.088730
# 2                   1.243011                   1.295900
# 3                   1.113190                   0.999835
# 4                   1.230317                   1.187360
# ..                       ...                        ...
# 414                 1.041977                   0.991744
# 415                 1.101963                   1.124190
# 416                 1.123164                   1.046940
# 417                 1.089656                   0.962743
# 418                 0.941077                   0.891100
#
#      stair_ascent_speed_max  stair_descent_speed_min  \
# 0                   1.28830                 0.675453
# 1                   1.71273                 0.718094
# 2                   1.65904                 1.112130
# 3                   1.91101                 0.662541
# 4                   1.85300                 0.664894
# ..                      ...                      ...
# 414                 1.65313                 0.830004
# 415                 1.39816                 0.680858
# 416                 2.38534                 0.665730
# 417                 1.54806                 0.686101
# 418                 1.84686                 0.660714
#
#      stair_descent_speed_mean  stair_descent_speed_median  \
# 0                    1.078890                    0.995578
# 1                    1.344225                    1.089250
# 2                    1.385570                    1.366755
# 3                    1.372438                    1.508720
# 4                    1.212054                    1.248305
# ..                        ...                         ...
# 414                  1.279828                    1.236100
# 415                  0.938817                    0.862358
# 416                  1.341530                    1.139880
# 417                  1.084077                    0.965200
# 418                  1.074825                    1.049140
#
#      stair_descent_speed_max  step_count  vo2_max  walking_asymmetry_min  \
# 0                    2.21127       20193    48.62                    0.0
# 1                    3.73039       25412    48.74                    0.0
# 2                    1.69664       19616    48.72                    0.0
# 3                    2.18718       16027    48.65                    0.0
# 4                    1.75090       23944    48.67                    0.0
# ..                       ...         ...      ...                    ...
# 414                  1.95940        6764      NaN                    NaN
# 415                  1.86641       13894    46.74                    0.0
# 416                  3.29447       21455    46.74                    0.0
# 417                  2.09338       14798    46.65                    0.0
# 418                  1.93291       13249    46.58                    0.0
#
#      walking_asymmetry_mean  walking_asymmetry_median  walking_asymmetry_max  \
# 0                  0.000000                       0.0                   0.00
# 1                  0.000000                       0.0                   0.00
# 2                  0.000000                       0.0                   0.00
# 3                  0.018000                       0.0                   0.05
# 4                  0.000909                       0.0                   0.01
# ..                      ...                       ...                    ...
# 414                     NaN                       NaN                    NaN
# 415                0.000000                       0.0                   0.00
# 416                0.005000                       0.0                   0.10
# 417                0.000000                       0.0                   0.00
# 418                0.000000                       0.0                   0.00
#
#      walking_support_min  walking_support_mean  walking_support_median  \
# 0                  0.236              0.268172                  0.2640
# 1                  0.237              0.264552                  0.2600
# 2                  0.256              0.275357                  0.2715
# 3                  0.239              0.267333                  0.2620
# 4                  0.220              0.251339                  0.2470
# ..                   ...                   ...                     ...
# 414                0.256              0.289000                  0.2950
# 415                0.249              0.270615                  0.2630
# 416                0.257              0.272431                  0.2705
# 417                0.243              0.270194                  0.2670
# 418                0.245              0.270567                  0.2675
#
#      walking_support_max  walking_heartrate_mean  walking_speed_min  \
# 0                  0.310                    95.0            2.10272
# 1                  0.323                    97.0            1.74481
# 2                  0.326                    81.0            1.81192
# 3                  0.309                   102.0            2.03561
# 4                  0.319                   119.0            1.61059
# ..                   ...                     ...                ...
# 414                0.313                    92.0            2.01324
# 415                0.321                   122.0            1.76718
# 416                0.307                   115.0            2.52774
# 417                0.323                    99.5            1.52112
# 418                0.320                   107.0            2.28168
#
#      walking_speed_mean  walking_speed_median  walking_speed_max  \
# 0              3.257710              3.489620            3.93701
# 1              3.392009              3.467250            4.31729
# 2              3.012570              3.176450            3.93701
# 3              3.289740              3.511990            4.18307
# 4              3.446407              3.556730            4.11596
# ..                  ...                   ...                ...
# 414            2.806113              2.796170            3.62384
# 415            3.170059              3.433695            3.78042
# 416            3.328022              3.411325            3.82516
# 417            3.290716              3.511990            3.98175
# 418            3.421792              3.579100            3.91464
#
#      walking_steplength_min  walking_steplength_mean  \
# 0                   19.6850                30.539961
# 1                   18.5039                31.145340
# 2                   20.8661                27.918541
# 3                   18.1102                29.705384
# 4                   16.1417                30.910016
# ..                      ...                      ...
# 414                 20.4724                28.237122
# 415                 16.5354                29.799421
# 416                 25.5906                30.593305
# 417                 16.1417                30.144741
# 418                 17.3228                31.445294
#
#      walking_steplength_median  walking_steplength_max
# 0                     31.88980                 35.8268
# 1                     31.88980                 36.2205
# 2                     29.13390                 33.8583
# 3                     30.70870                 36.6142
# 4                     31.49610                 36.6142
# ..                         ...                     ...
# 414                   28.93705                 36.2205
# 415                   31.88980                 33.4646
# 416                   30.51185                 33.8583
# 417                   31.10240                 34.6457
# 418                   33.07090                 34.6457
#
# [419 rows x 65 columns]

# %% [markdown]
# Got all the data together now, next step is EDA and data cleaning and then starting with the pipelines.

# %%
# Writing the data to CSV for quick random forest test in R
train.to_csv('train_prepped.csv', index=False)
test.to_csv('test_prepped.csv', index=False)
